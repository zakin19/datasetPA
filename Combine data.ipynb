# %%
import numpy as np
import pandas as pd

# %%
#dataset hasil survey
data1 = pd.read_csv('b_depressed.csv')

# %%
data1
# Out:
#       Survey_id  Ville_id  sex  Age  Married  Number_children  \
# 0           926        91    1   28        1                4
# 1           747        57    1   23        1                3
# 2          1190       115    1   22        1                3
# 3          1065        97    1   27        1                2
# 4           806        42    0   59        0                4
# ...         ...       ...  ...  ...      ...              ...
# 1424        255        22    1   25        1                1
# 1425        547        69    1   28        1                4
# 1426        893       184    1   66        0                0
# 1427        363        75    1   51        1                1
# 1428        231        12    1   33        0                4
#
#       education_level  total_members  gained_asset  durable_asset  ...  \
# 0                  10              5      28912201       22861940  ...
# 1                   8              5      28912201       22861940  ...
# ...

# %%
sex, age, married, education level, depressed, incoming_business

# %%
data1=data1.drop(['Survey_id', 'Ville_id','Number_children','total_members','gained_asset','durable_asset','save_asset',
       'living_expenses', 'other_expenses', 'incoming_salary',
       'incoming_own_farm', 'incoming_no_business',
       'incoming_agricultural', 'farm_expenses', 'labor_primary',
       'lasting_investment', 'no_lasting_investmen'], axis='columns')

# %%
data1.head()
# Out:
#    sex  Age  Married  education_level  incoming_business  depressed
# 0    1   28        1               10                  0          0
# 1    1   23        1                8                  0          1
# 2    1   22        1                9                  0          0
# 3    1   27        1               10                  0          0
# 4    0   59        0               10                  0          0

# %% [markdown]
# Dataset diatas
# Dataset terlibat dalam analisis depresi. Data tersebut terdiri dari studi tentang kondisi kehidupan masyarakat yang tinggal di wilayah pedesaan. Karena semua kolom tidak dijelaskan dalam tantangan ini sehingga Kami tidak dapat memahaminya. Kami melanjutkan untuk menghapusnya atau mengabaikannya. Fitur atau kolom terakhir adalah sebagai berikut:
#
# -Survey id Ville id
# -jenis kelamin
# -Usia
# -Menikah
# -Jumlah anak tingkat pendidikan
# -jumlah anggota (dalam keluarga) diperoleh aset
# -tahan lama aset simpan aset biaya
# -hidup pengeluaran lain gaji masuk masuk
# -pertanian sendiri masuk bisnis masuk tidak ada usaha masuk pertanian biaya pertanian tenaga kerja investasi utama abadi tidak --ada investasi abadi tertekan : [ Nol: Tidak tertekan] atau [Satu: tertekan] (Binary untuk kelas target)
#
#
#
#
#
# tujuan utamanya adalah untuk menunjukkan analisis statistik dan beberapa teknik data mining. Dataset memiliki 23 kolom o dimensi y un total de 1432 objek atau registros.

# %%
data1.columns
# Out:
# Index(['sex', 'Age', 'Married', 'education_level', 'incoming_business',
#        'depressed'],
#       dtype='object')

# %%
data6 = pd.read_excel('Effects of Depression  Anxiety on Academic Performance among the students (respuestas).xlsx')
data6.head()
# Out:
#   Gender:              Age:     Educational Level  \
# 0    Male    19 to 24 years  College - Bachelor's
# 1    Male    19 to 24 years  College - Bachelor's
# 2  Female  18 years or less           High School
# 3  Female  18 years or less           High School
# 4    Male  18 years or less           High School
#
#    Little interest or pleasure in doing things   \
# 0                                             3
# 1                                             2
# 2                                             2
# 3                                             3
# 4                                             1
#
#    Feeling down, depressed, or hopeless  \
# 0                                     2
# 1                                     1
# 2                                     2
# 3                                     1
# 4                                     2
#
#    Trouble falling or staying asleep, or sleeping too much  \
# 0                                                  4
# ...

# %%
data6.columns
# Out:
# Index(['Gender:', 'Age:', 'Educational Level',
#        'Little interest or pleasure in doing things ',
#        'Feeling down, depressed, or hopeless',
#        'Trouble falling or staying asleep, or sleeping too much',
#        'Feeling tired or having little energy', 'Poor appetite or overeating',
#        'Feeling bad about yourself or that you are a failure or not have let yourself or your family down',
#        'Trouble concentrating on things, such as reading the newspaper or watching television',
#        'Moving or speaking so slowly that other people could have noticed Or being so restless that you have been moving around a lot more than usual',
#        'Thoughts that you would be better off dead or of hurting yourself in some way',
#        'Do you have part-time or full-time job? ',
#        'Which of the following best describes your term-time accommodation?',
#        'How many hours do you spend studying each day?',
# ...

# %%
data6=data6.drop(['Gender:', 'Age:', 'Educational Level',
       'Little interest or pleasure in doing things ',
       'Feeling down, depressed, or hopeless',
       'Trouble falling or staying asleep, or sleeping too much',
       'Feeling tired or having little energy', 'Poor appetite or overeating',
       'Feeling bad about yourself or that you are a failure or not have let yourself or your family down',
       'Trouble concentrating on things, such as reading the newspaper or watching television',
       'Moving or speaking so slowly that other people could have noticed Or being so restless that you have been moving around a lot more than usual',
       'Thoughts that you would be better off dead or of hurting yourself in some way','Your Last Semester GPA: '], axis='columns')

# %%
data6.head()
# Out:
#   Do you have part-time or full-time job?   \
# 0                                Part time
# 1                                Part time
# 2                                       No
# 3                                       No
# 4                                Part time
#
#   Which of the following best describes your term-time accommodation?  \
# 0                                Home (with parents)
# 1                       University hall of residence
# 2                                Home (with parents)
# 3                                Home (with parents)
# 4                                Home (with parents)
#
#   How many hours do you spend studying each day?  \
# 0                                    2 - 4 hours
# 1                                    1 - 2 hours
# 2                                    1 - 2 hours
# 3                                    1 - 2 hours
# 4                                    1 - 2 hours
#
# ...

# %%
#kesehatan mental di tempat kerja
data9 = pd.read_csv('survey.csv')
data9
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
data9.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# family history, treatment,  work_interfere

# %%
data9=data9.drop(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
       'no_employees',
       'remote_work', 'tech_company', 'benefits', 'care_options',
       'wellness_program', 'seek_help', 'anonymity', 'leave',
       'mental_health_consequence', 'phys_health_consequence', 'coworkers',
       'supervisor', 'mental_health_interview', 'phys_health_interview',
       'mental_vs_physical', 'obs_consequence', 'comments'], axis='columns')

# %%
data9.head()
# Out:
#   family_history treatment work_interfere
# 0             No       Yes          Often
# 1             No        No         Rarely
# 2             No        No         Rarely
# 3            Yes       Yes          Often
# 4             No        No          Never

# %%
result = pd.concat([data1, data6, data9], axis=1, join="inner")

# %%
result.head()
# Out:
#    sex  Age  Married  education_level  incoming_business  depressed  \
# 0    1   28        1               10                  0          0
# 1    1   23        1                8                  0          1
# 2    1   22        1                9                  0          0
# 3    1   27        1               10                  0          0
# 4    0   59        0               10                  0          0
#
#   Do you have part-time or full-time job?   \
# 0                                Part time
# 1                                Part time
# 2                                       No
# 3                                       No
# 4                                Part time
#
#   Which of the following best describes your term-time accommodation?  \
# 0                                Home (with parents)
# 1                       University hall of residence
# 2                                Home (with parents)
# 3                                Home (with parents)
# ...

# %%
result
# Out:
#      sex  Age  Married  education_level  incoming_business  depressed  \
# 0      1   28        1               10                  0          0
# 1      1   23        1                8                  0          1
# 2      1   22        1                9                  0          0
# 3      1   27        1               10                  0          0
# 4      0   59        0               10                  0          0
# ..   ...  ...      ...              ...                ...        ...
# 347    1   39        1                9                  0          0
# 348    1   22        1               10                  0          0
# 349    1   20        1                9                  0          0
# 350    1   28        1                5                  0          1
# 351    1   26        1                8                  0          0
#
#     Do you have part-time or full-time job?   \
# 0                                  Part time
# ...

# %%
data_list=[data1,data6,data9]

# %%
data_result=pd.concat(data_list, axis=1)

# %%
data_result
# Out:
#       sex  Age  Married  education_level  incoming_business  depressed  \
# 0       1   28        1               10                  0          0
# 1       1   23        1                8                  0          1
# 2       1   22        1                9                  0          0
# 3       1   27        1               10                  0          0
# 4       0   59        0               10                  0          0
# ...   ...  ...      ...              ...                ...        ...
# 1424    1   25        1                7                  0          0
# 1425    1   28        1               10                  0          0
# 1426    1   66        0                1                  0          1
# 1427    1   51        1               12                  0          0
# 1428    1   33        0                8                  0          0
#
#      Do you have part-time or full-time job?   \
# 0                                   Part time
# ...
